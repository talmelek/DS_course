# %%
#создаем словарь
student = {
    "name": "Аркадий",
    "age": "18",
    "year": "1",
    "studies": ["Высшая математика", "Строение вещества", "Неорганическая химия", "Латинский язык"]
    }
#получаем значение
studies_list = student["studies"]
#выводим список предметов
print("Изучаемые предметы:", studies_list)
# Out:
# Изучаемые предметы: ['Высшая математика', 'Строение вещества', 'Неорганическая химия', 'Латинский язык']
