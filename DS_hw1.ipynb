# %%
#создаем словарь
student = {"name": "Аркадий", "Возраст": "18", "Курс": "1", "Предметы": ["Высшая математика", "Строение вещества", "Неорганическая химия", "Латинский язык"]}
#получаем значение
studies = student["Предметы"]
#выводим список предметов
print("Изучаемые предметы", studies)
# Out:
# Изучаемые предметы ['Высшая математика', 'Строение вещества', 'Неорганическая химия', 'Латинский язык']
